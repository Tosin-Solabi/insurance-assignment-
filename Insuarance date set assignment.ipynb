# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %%
tf=pd.read_csv('train_data.csv')

# %%
sf =pd.read_csv('train_data.csv',index_col='Customer Id')

# %%
sf
# Out:
#              YearOfObservation  Insured_Period  Residential Building_Painted  \
# Customer Id
# H14663                    2013        1.000000            0                N
# H2037                     2015        1.000000            0                V
# H3802                     2014        1.000000            0                N
# H3834                     2013        1.000000            0                V
# H5053                     2014        1.000000            0                V
# ...                        ...             ...          ...              ...
# H5290                     2012        1.000000            1                V
# H5926                     2013        1.000000            0                V
# H6204                     2016        0.038251            0                V
# H6537                     2013        1.000000            0                V
# H7470                     2014        1.000000            0                V
#
#             Building_Fenced Garden Settlement  Building Dimension  \
# Customer Id
# H14663                    V      V          U               290.0
# H2037                     N      O          R               490.0
# H3802                     V      V          U               595.0
# H3834                     V      V          U              2840.0
# H5053                     N      O          R               680.0
# ...                     ...    ...        ...                 ...
# H5290                     V      V          U                 NaN
# H5926                     V      V          U                 NaN
# H6204                     V      V          U                 NaN
# H6537                     V      V          U                 NaN
# H7470                     V      V          U                 NaN
#
#              Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# Customer Id
# H14663                   1             1960.0               .     1053      0
# H2037                    1             1850.0               4     1053      0
# H3802                    1             1960.0               .     1053      0
# H3834                    1             1960.0               .     1053      0
# H5053                    1             1800.0               3     1053      0
# ...                    ...                ...             ...      ...    ...
# H5290                    1             2001.0               .      NaN      0
# H5926                    2             1980.0               .      NaN      1
# H6204                    1             1992.0               .      NaN      0
# H6537                    1             1972.0               .      NaN      0
# H7470                    1             2004.0               .      NaN      0
#
# [7160 rows x 13 columns]

# %%
tf
# Out:
#      Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0         H14663               2013        1.000000            0
# 1          H2037               2015        1.000000            0
# 2          H3802               2014        1.000000            0
# 3          H3834               2013        1.000000            0
# 4          H5053               2014        1.000000            0
# ...          ...                ...             ...          ...
# 7155       H5290               2012        1.000000            1
# 7156       H5926               2013        1.000000            0
# 7157       H6204               2016        0.038251            0
# 7158       H6537               2013        1.000000            0
# 7159       H7470               2014        1.000000            0
#
#      Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                   N               V      V          U               290.0
# 1                   V               N      O          R               490.0
# 2                   N               V      V          U               595.0
# 3                   V               V      V          U              2840.0
# 4                   V               N      O          R               680.0
# ...               ...             ...    ...        ...                 ...
# 7155                V               V      V          U                 NaN
# 7156                V               V      V          U                 NaN
# 7157                V               V      V          U                 NaN
# 7158                V               V      V          U                 NaN
# 7159                V               V      V          U                 NaN
#
#       Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0                 1             1960.0               .     1053      0
# 1                 1             1850.0               4     1053      0
# 2                 1             1960.0               .     1053      0
# 3                 1             1960.0               .     1053      0
# 4                 1             1800.0               3     1053      0
# ...             ...                ...             ...      ...    ...
# 7155              1             2001.0               .      NaN      0
# 7156              2             1980.0               .      NaN      1
# 7157              1             1992.0               .      NaN      0
# 7158              1             1972.0               .      NaN      0
# 7159              1             2004.0               .      NaN      0
#
# [7160 rows x 14 columns]

# %%
tf.head(n=11)
# Out:
#    Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0       H14663               2013        1.000000            0
# 1        H2037               2015        1.000000            0
# 2        H3802               2014        1.000000            0
# 3        H3834               2013        1.000000            0
# 4        H5053               2014        1.000000            0
# 5        H4977               2012        1.000000            0
# 6        H7390               2012        1.000000            0
# 7       H14488               2015        1.000000            0
# 8       H19355               2014        1.000000            0
# 9       H18601               2015        1.000000            0
# 10      H18177               2013        0.241096            0
#
#    Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                 N               V      V          U               290.0
# 1                 V               N      O          R               490.0
# 2                 N               V      V          U               595.0
# 3                 V               V      V          U              2840.0
# 4                 V               N      O          R               680.0
# 5                 V               N      O          R               535.0
# 6                 N               V      V          U              2830.0
# 7                 N               V      V          U              4952.0
# 8                 V               N      O          R              2735.0
# 9                 V               N      O          R               520.0
# 10                V               N      O          R               550.0
#
#     Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0               1             1960.0               .     1053      0
# 1               1             1850.0               4     1053      0
# 2               1             1960.0               .     1053      0
# 3               1             1960.0               .     1053      0
# 4               1             1800.0               3     1053      0
# 5               1             1980.0               3     1143      0
# 6               1             1988.0               .     1143      0
# 7               1             1988.0               .     1160      0
# 8               1             2013.0               3     1173      1
# 9               1             2011.0               2     1224      0
# 10              1             1960.0               3     1283      0

# %%
tf.shape
# Out:
# (7160, 14)

# %%
tf.isnull().sum()
# Out:
# Customer Id             0
# YearOfObservation       0
# Insured_Period          0
# Residential             0
# Building_Painted        0
# Building_Fenced         0
# Garden                  7
# Settlement              0
# Building Dimension    106
# Building_Type           0
# Date_of_Occupancy     508
# NumberOfWindows         0
# Geo_Code              102
# Claim                   0
# dtype: int64

# %%
tf['Garden'].isnull().value_counts()/len(tf)
# Out:
# False    0.999022
# True     0.000978
# Name: Garden, dtype: float64

# %%
tf['Building Dimension'].isnull().value_counts()/len(tf)
# Out:
# False    0.985196
# True     0.014804
# Name: Building Dimension, dtype: float64

# %%
tf['Date_of_Occupancy'].isnull().value_counts()/len(tf)
# Out:
# False    0.92905
# True     0.07095
# Name: Date_of_Occupancy, dtype: float64

# %%
tf['Geo_Code'].isnull().value_counts()/len(tf)
# Out:
# False    0.985754
# True     0.014246
# Name: Geo_Code, dtype: float64

# %%
tf['Garden'].mode()
# Out:
# 0    O
# dtype: object

# %%
tf['Garden'].fillna(tf['Garden'].mode()[0], inplace=True)

# %%
tf['Building Dimension'].median()
# Out:
# 1083.0

# %%
tf['Building Dimension'].fillna(tf['Building Dimension'].median(), inplace=True)

# %%
tf['Date_of_Occupancy'].median()
# Out:
# 1970.0

# %%
tf['Date_of_Occupancy'].fillna(tf['Date_of_Occupancy'].median(), inplace=True)

# %%
tf['Geo_Code'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     612         try:
# --> 613             values = values.astype("f8")
#     614         except ValueError as err:
#
# ValueError: could not convert string to float: '2A004'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9453b83c4803> in <module>
# ----> 1 str(tf['Geo_Code'].median())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     614         except ValueError as err:
#     615             # e.g. "could not convert string to float: 'a'"
# --> 616             raise TypeError from err
#     617         if mask is not None:
#     618             values[mask] = np.nan
#
# TypeError:

# %%
tf.isnull().sum()
# Out:
# Customer Id             0
# YearOfObservation       0
# Insured_Period          0
# Residential             0
# Building_Painted        0
# Building_Fenced         0
# Garden                  0
# Settlement              0
# Building Dimension      0
# Building_Type           0
# Date_of_Occupancy       0
# NumberOfWindows         0
# Geo_Code              102
# Claim                   0
# dtype: int64
